# %%
"""feature scaling - to ccumulate all scatteed points to a particular point to get accurate model performance
types- normalization and its implementation(min max scaler)- ((Xi-min)/(max-min))(max_range-min_range)+min_range
- standarddization and implementation (z score/ standard scaler)= (Xi -x)/sd"""
# Out:
# 'feature scaling - \ntypes- normalization and its implementation\n- standarddization and implementation'

# %%
#feature scaling
#Normalization
import pandas as pd
from sklearn.preprocessing import MinMaxScaler

# %%
df=pd.read_csv("energy_dataset.csv")

# %%
df.head(3)
# Out:
#      Country  Year Energy Type  Production (GWh)  Installed Capacity (MW)  \
# 0        USA  2011       Solar      85404.690027              5549.794323
# 1  Australia  2008  Geothermal      22205.069382             43211.593798
# 2     Canada  2013     Biomass      94102.732038              6139.117212
#
#    Investments (USD)  Population           GDP  Energy Consumption  \
# 0       5.604125e+09  1064007213  1.775278e+14       369654.644184
# 1       6.361886e+08  1033255852  6.435372e+13       771781.636293
# 2       6.158680e+09    14895124  1.567926e+14       342707.152899
#
#    Energy Exports  ...  Economic Freedom Index  Ease of Doing Business  \
# 0    93087.198199  ...               49.216800               57.678605
# 1     1752.536054  ...               79.990942                1.761579
# 2    65146.592498  ...               94.374040               77.657334
#
#    Innovation Index  Number of Research Institutions  \
# 0         76.803228                              851
# ...

# %%
df.describe() #only for numeric values
# Out:
#               Year  Production (GWh)  Installed Capacity (MW)  \
# count  2500.000000       2500.000000              2500.000000
# mean   2011.437600      48743.195073             24882.910674
# std       6.895471      28340.915147             14463.459958
# min    2000.000000       1053.354158               114.531639
# 25%    2006.000000      24309.656479             12282.213159
# 50%    2011.000000      47367.117600             24689.162460
# 75%    2017.250000      73079.452832             37438.443570
# max    2023.000000      99937.503719             49997.387577
#
#        Investments (USD)    Population           GDP  Energy Consumption  \
# count       2.500000e+03  2.500000e+03  2.500000e+03         2500.000000
# mean        4.956155e+09  7.458927e+08  1.010745e+14       495701.245158
# std         2.894789e+09  4.373146e+08  5.782363e+13       291419.017957
# min         5.886994e+06  1.255357e+06  5.603965e+10         1264.851083
# ...

# %%
#we have convert categorical data to  numeric or have to drop it 
scaler=MinMaxScaler()

# %%
df.drop(columns=["Country","Energy Type"], inplace=True)

# %%
df[:]=scaler.fit_transform(df)
# Out:
# C:\Users\sai\AppData\Local\Temp\ipykernel_6644\2110798244.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.47826087 0.34782609 0.56521739 ... 0.95652174 0.         0.43478261]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df[:]=scaler.fit_transform(df)
# C:\Users\sai\AppData\Local\Temp\ipykernel_6644\2110798244.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.70933402 0.68880901 0.00910387 ... 0.93964665 0.5730697  0.29068513]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df[:]=scaler.fit_transform(df)
# ...

# %%
df
# Out:
#           Year  Production (GWh)  Installed Capacity (MW)  Investments (USD)  \
# 0     0.478261          0.853032                 0.108961           0.560249
# 1     0.347826          0.213904                 0.863965           0.063078
# 2     0.565217          0.940994                 0.120775           0.615747
# 3     0.434783          0.887084                 0.806071           0.852671
# 4     0.782609          0.932759                 0.614257           0.508421
# ...        ...               ...                      ...                ...
# 2495  1.000000          0.394784                 0.932897           0.558791
# 2496  0.739130          0.084956                 0.569178           0.560104
# 2497  0.956522          0.943288                 0.453923           0.859110
# 2498  0.000000          0.658882                 0.068470           0.563919
# 2499  0.434783          0.121175                 0.456592           0.273284
#
# ...

# %%
df.describe() #now data is consistent
# Out:
#               Year  Production (GWh)  Installed Capacity (MW)  \
# count  2500.000000       2500.000000              2500.000000
# mean      0.497287          0.482280                 0.496531
# std       0.299803          0.286607                 0.289949
# min       0.000000          0.000000                 0.000000
# 25%       0.260870          0.235187                 0.243925
# 50%       0.478261          0.468364                 0.492647
# 75%       0.750000          0.728389                 0.748231
# max       1.000000          1.000000                 1.000000
#
#        Investments (USD)   Population          GDP  Energy Consumption  \
# count        2500.000000  2500.000000  2500.000000         2500.000000
# mean            0.495403     0.497008     0.505430            0.495252
# std             0.289699     0.291886     0.289312            0.291900
# min             0.000000     0.000000     0.000000            0.000000
# ...

# %%
 
scaler=MinMaxScaler(feature_range=(1, 10))
df[:]=scaler.fit_transform(df)
df
# Out:
#            Year  Production (GWh)  Installed Capacity (MW)  Investments (USD)  \
# 0      5.304348          8.677287                 1.980645           6.042244
# 1      4.130435          2.925136                 8.775689           1.567703
# 2      6.086957          9.468945                 2.086972           6.541722
# 3      4.913043          8.983759                 8.254636           8.674035
# 4      8.043478          9.394829                 6.528309           5.575790
# ...         ...               ...                      ...                ...
# 2495  10.000000          4.553053                 9.396071           6.029119
# 2496   7.652174          1.764607                 6.122601           6.040933
# 2497   9.608696          9.489592                 5.085305           8.731988
# 2498   1.000000          6.929935                 1.616229           6.075270
# 2499   4.913043          2.090571                 5.109324           3.459555
#
# ...

# %%
df.describe()
# Out:
#               Year  Production (GWh)  Installed Capacity (MW)  \
# count  2500.000000       2500.000000              2500.000000
# mean      5.475583          5.340519                 5.468778
# std       2.698228          2.579465                 2.609537
# min       1.000000          1.000000                 1.000000
# 25%       3.347826          3.116686                 3.195326
# 50%       5.304348          5.215275                 5.433821
# 75%       7.750000          7.555498                 7.734081
# max      10.000000         10.000000                10.000000
#
#        Investments (USD)   Population          GDP  Energy Consumption  \
# count        2500.000000  2500.000000  2500.000000         2500.000000
# mean            5.458627     5.473076     5.548873            5.457266
# std             2.607290     2.626972     2.603805            2.627096
# min             1.000000     1.000000     1.000000            1.000000
# ...

# %%
#for standardization
from sklearn.preprocessing import StandardScaler
s= StandardScaler()

# %%
s.fit_transform(df)
# Out:
# array([[-0.06347464,  1.29384776, -1.33695424, ..., -0.82442719,
#          0.97628121, -0.94852309],
#        [-0.49862983, -0.93657649,  1.26749409, ...,  1.56489453,
#         -1.02429504,  1.05427059],
#        [ 0.22662883,  1.60081675, -1.29620045, ...,  0.60879423,
#          0.97628121, -0.94852309],
#        ...,
#        [ 1.53209441,  1.60882297, -0.14697997, ..., -0.848301  ,
#         -1.02429504,  1.05427059],
#        [-1.65904368,  0.61630367, -1.47662988, ..., -1.44393265,
#          0.97628121, -0.94852309],
#        [-0.20852637, -1.26018314, -0.13777403, ...,  1.44486513,
#         -1.02429504, -0.94852309]])

# %%
df
# Out:
#            Year  Production (GWh)  Installed Capacity (MW)  Investments (USD)  \
# 0      5.304348          8.677287                 1.980645           6.042244
# 1      4.130435          2.925136                 8.775689           1.567703
# 2      6.086957          9.468945                 2.086972           6.541722
# 3      4.913043          8.983759                 8.254636           8.674035
# 4      8.043478          9.394829                 6.528309           5.575790
# ...         ...               ...                      ...                ...
# 2495  10.000000          4.553053                 9.396071           6.029119
# 2496   7.652174          1.764607                 6.122601           6.040933
# 2497   9.608696          9.489592                 5.085305           8.731988
# 2498   1.000000          6.929935                 1.616229           6.075270
# 2499   4.913043          2.090571                 5.109324           3.459555
#
# ...

# %%
df.describe()
# Out:
#               Year  Production (GWh)  Installed Capacity (MW)  \
# count  2500.000000       2500.000000              2500.000000
# mean      5.475583          5.340519                 5.468778
# std       2.698228          2.579465                 2.609537
# min       1.000000          1.000000                 1.000000
# 25%       3.347826          3.116686                 3.195326
# 50%       5.304348          5.215275                 5.433821
# 75%       7.750000          7.555498                 7.734081
# max      10.000000         10.000000                10.000000
#
#        Investments (USD)   Population          GDP  Energy Consumption  \
# count        2500.000000  2500.000000  2500.000000         2500.000000
# mean            5.458627     5.473076     5.548873            5.457266
# std             2.607290     2.626972     2.603805            2.627096
# min             1.000000     1.000000     1.000000            1.000000
# ...
